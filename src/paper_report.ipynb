# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# %%
ven = pd.read_excel('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/data/venezia_papers.xlsx')
keep = ['Contact Presenter Full Name', 'Title',
        'Keywords', 'Abstract']
ven = ven[keep]
ven.columns = ['authors', 'title', 'keywords', 'abstract']

# %%
ven['title'] = ven['title'].apply(lambda x : x.lower().strip())

# %%
ven.head()
# Out:
#                     authors  \
# 0  Lucrezia Alice Moschetta
# 1             Emanuela Sala
# 2              Sara Landini
# 3         Nicola Caravaggio
# 4   Chiara Ludovica Comolli
#
#                                                title  \
# 0  who takes care of old migrant care workers in ...
# 1  older carers and the digitalisation of health ...
# 2                   the problem of abandoned embryos
# 3  the determinants of health expenditure: a mach...
# 4          mortality risk after bereavement in italy
#
#                                             keywords  \
# 0        Aging, Care, Migration, Care Workers, Italy
# 1              older carers, digital health services
# 2  embryos, adoption, familiy law, right to procr...
# 3  Machine Learning, National Health System, Heal...
# 4     pensioners; mortality; bereavement; inequality
#
#                                             abstract
# 0  This study delves into the intricate relations...
# 1  In Italy, the percentage of informal older car...
# 2  In Italian hospitals there are embryos, called...
# 3  Accurate forecasting of healthcare costs is es...
# 4  A rich literature documents that bereavement, ...

# %%
nap = pd.read_excel('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/data/napoli_papers.xlsx')
keep = ['authors_formatted', 'title', 'abstract', 'keywords']
nap = nap[keep]
nap.columns = ['authors', 'title', 'abstract', 'keywords']
nap = nap[['authors', 'title', 'keywords', 'abstract']]

# %%
nap['title'] = nap['title'].apply(lambda x : x.lower().strip())

# %%
nap.head()
# Out:
#                                              authors  \
# 0  Meacci, Valentino\nCastrignano, Lorenzo\nVerdi...
# 1                          Loberto, Francesca Romana
# 2  Komici, Klara\nBrunese, Maria Chiara\nRengo, G...
# 3  Landini, Sara\nViciani, Simona\nBiagioni, Giul...
# 4  Ferrara, Nicola\nPetraglia, Laura\nBencivenga,...
#
#                                                title  \
# 0  toward self-monitoring healthcare: an open pla...
# 1  voices from the margins: a poetic inquiry into...
# 2  unraveling functional decline: the relationshi...
# 3  women reproductive health in ageing society an...
# 4  aging lung: the association between muscle str...
#
#                                             keywords  \
# 0  Ultrasound, Ultraportable, Open platform, FPGA...
# 1  Aging, Listening Guide, Complexity, Ethics of ...
# 2  muscle strength, muscle ultrasound, handgrip s...
# 3                                     PMA, Insurance
# 4  Aging Lung, Sarcopenia, Pulmanary function, Ha...
#
#                                             abstract
# 0  <p>The increasing prevalence of chronic diseas...
# 1  <p>This qualitative research is an in-depth ex...
# 2  <p>Background: Skeletal muscle characteristics...
# 3  <p>The research starts from data on access to ...
# 4  <p>Ageing is characterized by rigidity of ches...

# %%
# ven, nap must exist and both have a 'title' column
s1 = set(ven["title"].astype(str).str.strip().str.lower().dropna())
s2 = set(nap["title"].astype(str).str.strip().str.lower().dropna())

plt.figure(figsize=(6, 6))
venn2([s1, s2], set_labels=("ven", "nap"))
plt.title("Overlap of titles")
plt.show()

# (optional) print counts
print("ven unique titles:", len(s1))
print("nap unique titles:", len(s2))
print("intersection:", len(s1 & s2))
print("only ven:", len(s1 - s2))
print("only nap:", len(s2 - s1))
# Out:
# ven unique titles: 280
# nap unique titles: 374
# intersection: 7
# only ven: 273
# only nap: 367

# %%
cen_papers = pd.read_csv('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/data/2026-01-09T11-54_papers.csv')
keep = ['title', 'authors_full', 'abstract']
cen_papers = cen_papers[keep]
cen_papers.columns = ['title', 'authors', 'abstract']

# %%
cen_papers.head()
# Out:
#                                                title  \
# 0  Communicating complex statistical models to a ...
# 1  Towards a turnkey approach for unbiased Monte ...
# 2       eXplainable AI for word embeddings: A survey
# 3  for Spatio-temporal Modelling of Repeated Cros...
# 4  Addressing topic modelling via reduced latent ...
#
#                                              authors  \
# 0  Mattia Stival, Lorenzo Schiavon, Gaia Bertarel...
# 1  Nicolas Chopin, Francesca R Crucinio, Sumeetpa...
# 2      Roberto Boselli, Simone D’Amico, Navid Nobani
# 3                    Lorenzo Schiavon, Mattia Stival
# 4                                   Lorenzo Schiavon
#
#                                             abstract
# 0  Abstract Background . Effectively communicatin...
# 1  Abstract Given a smooth function $ f $, we dev...
# 2                                                NaN
# 3                                                NaN
# 4  Abstract In the social sciences, topic modelli...

# %%
conf = pd.concat([ven, nap])

# %%
conf
# Out:
#                                                authors  \
# 0                             Lucrezia Alice Moschetta
# 1                                        Emanuela Sala
# 2                                         Sara Landini
# 3                                    Nicola Caravaggio
# 4                              Chiara Ludovica Comolli
# ..                                                 ...
# 369                              Cavaliere, Annachiara
# 370  Gambardella, Jessica\nFiordelisi, Antonella\nC...
# 371  Garifalos, Francesco\nMenafra, Davide\nde Ange...
# 372                                 Virgolesi, Michele
# 373  Lettera, Vincenzo\nCacciatore, Giuseppina\nIll...
#
#                                                  title  \
# 0    who takes care of old migrant care workers in ...
# 1    older carers and the digitalisation of health ...
# 2                     the problem of abandoned embryos
# 3    the determinants of health expenditure: a mach...
# 4            mortality risk after bereavement in italy
# ..                                                 ...
# 369  beyond the skin: integrating mhealth and multi...
# 370  role of mitochondrial dysfunction in the patho...
# 371  innovative intervention supported by digital t...
# 372  the role of nursing in promoting health for ag...
# 373  proteomic analysis of red blood cell membrane ...
#
#                                               keywords  \
# 0          Aging, Care, Migration, Care Workers, Italy
# 1                older carers, digital health services
# 2    embryos, adoption, familiy law, right to procr...
# 3    Machine Learning, National Health System, Heal...
# 4       pensioners; mortality; bereavement; inequality
# ..                                                 ...
# 369  Hidradenitis Suppurativa, mHealth, Multidiscip...
# 370  Fabry Disease, Mitochondrial Dysfunction, Mito...
# 371                 Hypogonadism; mHealth; Unmet Needs
# 372  Active Aging, Nursing Competencies, Person-Cen...
# 373  RBC Membrane Proteomics; Aging Biomarkers, Inf...
#
#                                               abstract
# 0    This study delves into the intricate relations...
# 1    In Italy, the percentage of informal older car...
# 2    In Italian hospitals there are embryos, called...
# 3    Accurate forecasting of healthcare costs is es...
# 4    A rich literature documents that bereavement, ...
# ..                                                 ...
# 369  <p><strong>Introduction</strong>: Hidradenitis...
# 370  <p><strong>Introduction</strong>: Fabry diseas...
# 371  <p>Hypogonadism is a condition in which there ...
# 372  <p><strong>Background</strong> As the proporti...
# 373  <p>Aging is a complex biological process invol...
#
# [654 rows x 4 columns]

# %%
cen_papers.head()
# Out:
#                                                title  \
# 0  Communicating complex statistical models to a ...
# 1  Towards a turnkey approach for unbiased Monte ...
# 2       eXplainable AI for word embeddings: A survey
# 3  for Spatio-temporal Modelling of Repeated Cros...
# 4  Addressing topic modelling via reduced latent ...
#
#                                              authors  \
# 0  Mattia Stival, Lorenzo Schiavon, Gaia Bertarel...
# 1  Nicolas Chopin, Francesca R Crucinio, Sumeetpa...
# 2      Roberto Boselli, Simone D’Amico, Navid Nobani
# 3                    Lorenzo Schiavon, Mattia Stival
# 4                                   Lorenzo Schiavon
#
#                                             abstract
# 0  Abstract Background . Effectively communicatin...
# 1  Abstract Given a smooth function $ f $, we dev...
# 2                                                NaN
# 3                                                NaN
# 4  Abstract In the social sciences, topic modelli...

# %%
# ven, cen_papers must exist and both have a 'title' column
s1 = set(conf["title"].astype(str).str.strip().str.lower().dropna())
s2 = set(cen_papers["title"].astype(str).str.strip().str.lower().dropna())

plt.figure(figsize=(6, 6))
venn2([s1, s2], set_labels=("conf", "cen_papers"))
plt.title("Overlap of titles")
plt.show()

# (optional) print counts
print("conf unique titles:", len(s1))
print("cen_papers unique titles:", len(s2))
print("intersection:", len(s1 & s2))
print("only conf:", len(s1 - s2))
print("only cen_papers:", len(s2 - s1))
# Out:
# conf unique titles: 647
# cen_papers unique titles: 1122
# intersection: 26
# only conf: 621
# only cen_papers: 1096
