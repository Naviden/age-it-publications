# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/src/keywords.csv')

# %%
df[['keywords']].to_csv('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/data/processed/keyword_data.csv', index=False)
