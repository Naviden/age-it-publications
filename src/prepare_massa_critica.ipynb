# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/navid/Documents/1_Projects/0_Age-It/Our Tasks/Mario_report/data/Personale Age-It.xlsx', sheet_name='personale massa critica')

# %%
df.columns
# Out:
# Index(['Codice', 'Soggetto', 'CUP', 'Nome', 'Cognome', 'Codice fiscale',
#        'Inquadramento contrattuale', 'Impegno contrattuale',
#        'Modalità di rendicontazione', 'Livello', 'Costo orario €',
#        'Ruolo ricoperto'],
#       dtype='object')

# %%
df = df[['Nome', 'Cognome', 'Codice fiscale',
       'Inquadramento contrattuale']]

# %%
df['MC'] = True

# %%
df
# Out:
#            Nome       Cognome    Codice fiscale  \
# 0       Daniela  Trisciuoglio  TRSDNL73R55H501N
# 1       Tiziana       Tesauro  TSRTZN71H58F205V
# 2       Pietro      Siciliano  SCLPRL60D26I549H
# 3       Serena          Sanna  SNNSRN80S55H856X
# 4        Paolo       Matteini  MTTPLA77B04D612X
# ..          ...           ...               ...
# 372   Giuseppe      Passarino  PSSGPP64A07D086R
# 373     Massimo      Armenise  RMNMSM78H23A662X
# 374      Elvira     Filicetti  FLCLVR86R63D086K
# 375        Luca        Soraci  SRCLCU89D01F158E
# 376  Gianfranco       Santoro  SNTGFR70S13H501C
#
#           Inquadramento contrattuale    MC
# 0                       Ricercatore   True
# 1          Ricercatore (III livello)  True
# 2    Dirigente di Ricerca, I Livello  True
# 3               Dirigente di Ricerca  True
# 4    Dirigente di Ricerca, I Livello  True
# ..                               ...   ...
# 372                               PO  True
# ...

# %%
df.to_csv('../data/processed/massa_critica.csv', index=False)
